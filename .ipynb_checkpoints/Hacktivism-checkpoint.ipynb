# %% [markdown]
# Exploring the VCDB: Hacktivism
# ===============================
#
# This IPython notebook demonstrates some simple ways that analysts can begin working with VCDB data on their own. You should have at least basic familiarity with Python and [VERIS](http://veriscommunity.net), but no advanced skills or mathematical knowledge are required.
#
# First, we just load the VCDB dataset itself into Python. Normally you'd need to open and read each individual file within VCDB, but for this project we've already unified them into one large JSON file.
#
# **We should probably show how to do this.**

# %%
import json
with open('data/vcdb.json','rb') as f:
    vcdb = json.load(f)
print "%d incidents imported" % len(vcdb)
# Out:
# 3084 incidents imported

# %% [markdown]
# Looking at DoS incidents
# -------------------------
#
# Denial of Service (DoS) events are fairly common and well-understood, particularly the 'distributed' variety. Let's see how many of these we have in the dataset. Note that we use the `.get()` method for Python `dict`s so that we can default to an empty dictionary. We do this because not every incident will have the Hacking attribute (where the DoS enumeration is found), and so otherwise Python will complain and throw a `KeyError` on those without Hacking.

# %%
dos = []
for each in vcdb:
    variety = each.get('action').get('hacking', {}).get('variety', [])
    if 'DoS' in variety:
        dos.append(each)
print "%d incidents with action.hacking.variety.DoS" % len(dos)
# Out:
# 51 incidents with action.hacking.variety.DoS

# %% [markdown]
# We want to look more closely at these incidents to understand the motives (so far as we know them) for these incidents. We'll still use that `dict.get('attribute', {})` idiom to avoid issues, and we are assuming for simplicity's sake that we only want to look at the ones with external actors. (Hint: that's almost all of them anyway). Also, realize that `actor.external.motive` is an array in the VERIS schema so we can capture multiple motives, so we need to iterate through the list for each incident.

# %%
dos_motives = {}
for each in dos:
    motives = each.get('actor').get('external', {}).get('motive')
    for motive in motives:
        if motive in dos_motives:
            dos_motives[motive] += 1
        else:
            dos_motives[motive] = 1
print dos_motives
# Out:
# {u'Ideology': 18, u'Unknown': 19, u'Grudge': 6, u'Fun': 8}

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# IPython makes building a histogram of these data fairly straightforward.
#
# We can draw at least one interesting conclusion from that analysis: when we know the motive for a DoS attack, `Ideology` is listed more than half the time. Let's take a quick look at some "hacktivism" events.
#
# Hacktivism
# ----------
#
# The VERIS schema has two places where we might look to see if something is related to [hacktivism](https://en.wikipedia.org/wiki/Hacktivism). `actor.external.variety` includes an enumeration for Activist, and `actor.external.motive` includes Ideology. If an incident includes either of these, we want to see what happened. Because almost all of these incidents use the Hacking action exclusively, we can also gather data about the specifics of that action fairly easily.

# %%
hacktivism=[]
varieties = {}
for each in vcdb: #or 'Fun' in each.get('actor').get('external', {}).get('motive',[]) \
    if 'Activist' in each['actor'].get('external',{}).get('variety',[]) \
      or 'Ideology' in each.get('actor').get('external', {}).get('motive',[]):
        hacktivism.append(each)
        print each['action']
        variety = each['action'].get('hacking',{}).get('variety', [])
        for v in variety:
            if v == 'Unknown':
                continue
            if v in varieties:
                varieties[v] += 1
            else:
                varieties[v] = 1
# Out:
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'SQLi']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Use of stolen creds']}, u'social': {u'notes': u'Syrian Electronic Army is best known for its Spear Phishing attacks where employees of organization are targeted with malicious emails. It appears the group used the same attack to compromise the Mark Monitor account of Ebay. I presume the same technique was used for Paypal.', u'vector': [u'Email'], u'target': [u'End-user'], u'variety': [u'Phishing']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Unknown'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'DoS']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Unknown'], u'variety': [u'Unknown'], u'cve': u''}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Brute force']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Backdoor or C2'], u'variety': [u'Unknown']}}
# {u'physical': {u'notes': u'', u'vector': [u'Bypassed controls'], u'location': [u'Victim work area'], u'variety': [u'Theft']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'DoS']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Unknown'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'unknown': {}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'may be through web site', u'vector': [u'Unknown'], u'variety': [u'Unknown'], u'cve': u''}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'Syrian Electronic Army', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Unknown'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Unknown'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Unknown'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Brute force']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'SQLi']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Other'], u'variety': [u'Unknown'], u'cve': u''}}
# {u'hacking': {u'notes': u'', u'vector': [u'Unknown'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Unknown'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown'], u'cve': u''}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'SQLi'], u'cve': u''}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'DoS']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'social': {u'notes': u'"The person was able to impersonate myself with our Web hosting company, and provide correct answers to their verification questions. And thereby gain access to our client account with the host, and ultimately change the email and then request a mailing of the access details."', u'vector': [u'Phone'], u'target': [u'Call center'], u'variety': [u'Pretexting']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'DoS']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'SQLi activist', u'vector': [u'Web application'], u'variety': [u'SQLi']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'It seems that hacker got access to a server with multiple vulnerabilities, resulting in defaced the server', u'vector': [u'Web application'], u'variety': [u'Unknown'], u'cve': u'cve unknown'}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'DoS']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'Used stolen credentials to log into Twitter and Google Apps.', u'vector': [u'Web application'], u'variety': [u'Use of stolen creds'], u'cve': u''}, u'social': {u'notes': u'threat actor avoided sending messages to technical staff to evade detection.', u'vector': [u'Email'], u'target': [u'End-user'], u'variety': [u'Phishing']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown', u'Use of stolen creds']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Unknown'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Unknown'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'SQLi']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Use of stolen creds'], u'cve': u''}, u'social': {u'notes': u'', u'vector': [u'Email'], u'target': [u'Unknown'], u'variety': [u'Phishing']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Unknown'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Unknown'], u'variety': [u'DoS']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Other']}}
# {u'hacking': {u'vector': [u'Unknown'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'Anonymous China', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'DoS']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}, u'malware': {u'vector': [u'Direct install'], u'variety': [u'DoS']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Unknown'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'unknown': {}}
# {u'hacking': {u'notes': u'Anonymous', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'SQLi']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'SQLi']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Unknown'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'SQLi'], u'cve': u''}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'DoS']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Unknown'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Unknown'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Unknown'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Other']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Unknown'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Use of stolen creds'], u'cve': u''}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'CabinCr3W claimed responsibility', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Unknown'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'SQL injection not reported.  However, it has the look of an sql injection attack and CabinCr3w is known for using that type of attack frequently.', u'vector': [u'Web application'], u'variety': [u'SQLi'], u'cve': u''}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Brute force']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Unknown'], u'variety': [u'Unknown'], u'cve': u''}}
# {u'hacking': {u'notes': u'In an effort to prove this, we gained access to the schools website via CPANEL login http://tinypic.com/r/ot0wok/6, and the webmaster James "Jim" Parks http://www.facebook.com/BIGREDMANOWAR personal email http://tinypic.com/r/2gwbclj/6 which we promptly found multiple nude photographs in.  We in turn locked him out of his own email, and backed up the contents to the web to preserve evidence. http://www.filehosting.org/file/details/405512/Emails.zip', u'vector': [u'Web application'], u'variety': [u'Unknown'], u'cve': u''}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'unknown': {}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'OpLastResort', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown'], u'cve': u''}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'SQLi']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'social': {u'notes': u'', u'vector': [u'Email'], u'target': [u'Executive'], u'variety': [u'Extortion']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown'], u'cve': u''}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'defacement', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Unknown'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'SQLi']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'DoS']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'unknown': {}}
# {u'malware': {u'notes': u'code posted to forum would redirect users to por-Assad site.', u'vector': [u'Unknown'], u'variety': [u'Client-side attack']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'SQLi'], u'cve': u''}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown'], u'cve': u''}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Unknown'], u'variety': [u'Unknown'], u'cve': u''}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'SQLi']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown'], u'cve': u''}}
# {u'hacking': {u'notes': u'A member of the infamous Anonymous group, known as Darwinaire, is claiming responsibility for the theft.', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'DoS']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'DoS']}}
# {u'hacking': {u'notes': u'The Israeli Hackers Team', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Unknown'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Abuse of functionality']}}
# {u'hacking': {u'notes': u'Unknown how the actor got the stolen credentials in the first place.', u'vector': [u'Web application'], u'variety': [u'Unknown', u'Use of stolen creds']}}
# {u'hacking': {u'vector': [u'Unknown'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'SQLi']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Unknown'], u'variety': [u'DoS']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'DoS']}}
# {u'hacking': {u'notes': u'Database was corrupted, website offline, making a leap on SQLi. ', u'vector': [u'Web application'], u'variety': [u'Unknown'], u'cve': u''}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown'], u'cve': u''}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown', u'DoS'], u'cve': u''}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'DoS']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Unknown'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'SQLi']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Unknown'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Unknown'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'DoS']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'DoS']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'SQLi']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'SQLi']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Unknown'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Unknown'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'DoS']}}
# {u'hacking': {u'notes': u'browser exploit.', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Unknown'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Unknown'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'defacement', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'SQLi']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Unknown'], u'variety': [u'Brute force'], u'cve': u''}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'SQLi']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'Details of the hack at http://cryptome.org/2013/02/parastoo-janes-cbrn.htm', u'vector': [u'Web application'], u'variety': [u'Brute force', u'SQLi'], u'cve': u''}}
# {u'hacking': {u'notes': u'probably vector=web application, but not certain.', u'vector': [u'Unknown'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Unknown'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'XSS']}}
# {u'hacking': {u'notes': u'DNS', u'vector': [u'Other'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Unknown'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Unknown'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Unknown'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'DoS']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'DoS']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'DoS']}}
# {u'hacking': {u'notes': u'The leaked data has been uploaded to anonfiles.me in the format of a compressed rar file that contains the complete database extraction from the site in CSV format', u'vector': [u'Backdoor or C2'], u'variety': [u'Other']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown'], u'cve': u''}}
# {u'hacking': {u'notes': u'in support of Anonymous Sweden', u'vector': [u'Web application'], u'variety': [u'SQLi']}}
# {u'hacking': {u'notes': u'Anonymous', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Unknown'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Other'], u'variety': [u'Other']}}
# {u'hacking': {u'vector': [u'Unknown'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown'], u'cve': u''}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Use of stolen creds']}, u'social': {u'notes': u'Syrian Electronic Army is best known for its Spear Phishing attacks where employees of organization are targeted with malicious emails. It appears the group used the same attack to compromise the Mark Monitor account of Ebay.', u'vector': [u'Email'], u'target': [u'End-user'], u'variety': [u'Phishing']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'A group calling itself the "Inj3ct0r Team" claimed responsibility for the attack', u'vector': [u'Web application'], u'variety': [u'Abuse of functionality']}}
# {u'misuse': {u'vector': [u'Physical access'], u'variety': [u'Privilege abuse']}, u'error': {u'vector': [u'Carelessness'], u'variety': [u'Other']}}
# {u'hacking': {u'vector': [u'Unknown'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Unknown'], u'variety': [u'DoS']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown'], u'cve': u''}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'VPN', u'Web application'], u'variety': [u'Use of stolen creds'], u'cve': u''}, u'social': {u'notes': u'', u'vector': [u'Email'], u'target': [u'End-user'], u'variety': [u'Phishing']}}
# {u'hacking': {u'vector': [u'Unknown'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Unknown'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown'], u'cve': u''}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Unknown'], u'variety': [u'Unknown'], u'cve': u''}}
# {u'hacking': {u'notes': u'Guccifer', u'vector': [u'Unknown'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'Using the AtomicReferenceArray vulnerability on Java', u'vector': [u'Unknown'], u'variety': [u'Other'], u'cve': u'CVE-2012-0507'}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Physical access'], u'variety': [u'Use of stolen creds']}, u'physical': {u'vector': [u'Uncontrolled location'], u'location': [u'Public facility'], u'variety': [u'Tampering']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'DoS']}}
# {u'hacking': {u'vector': [u'Unknown'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'DoS']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'misuse': {u'vector': [u'LAN access'], u'variety': [u'Privilege abuse']}, u'hacking': {u'vector': [u'Web application'], u'variety': [u'Use of stolen creds']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Unknown'], u'variety': [u'DoS']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'hacking': {u'vector': [u'Unknown'], u'variety': [u'Unknown']}}
# {u'hacking': {u'notes': u'', u'vector': [u'Web application'], u'variety': [u'Unknown']}}
# {u'unknown': {}}

# %%
print len(hacktivism)
# Out:
# 312

# %%
print varieties
# Out:
# {u'XSS': 1, u'Use of stolen creds': 10, u'SQLi': 21, u'Brute force': 5, u'Other': 5, u'DoS': 25, u'Abuse of functionality': 2}

# %%
labels = sorted(varieties, key=varieties.get)
values = [varieties[x] for x in labels]
ypos = np.arange(len(varieties))+.1
plt.barh(ypos,values,color="red",align="center",height=.9)

# Adds some padding to the bars so that it doesn't butt up 
# against the edge of the image
plt.xlim(0,max(values)*1.1)
plt.yticks(ypos,labels)
plt.title("Hacking variety for Hacktivists. n = %s" % len(hacktivism))
plt.show()

# %% [markdown]
# Conclusion
# ----------
#
# Using denial of service and hacktivism as motivating examples, we've illustrated some of the ways to interact with VERIS data and the VCDB using simple Python techniques and even done a tiny bit of simple data visualization. Future sample analyses will delve further into visualization and data transformation, but in the meantime you can reach the authors of this analysis at [@kylemaxwell](https://twitter.com/kylemaxwell) or [@bfist](https://twitter.com/bfist), or see the [VERIS community](http://veriscommunity.net) for broader questions and support.
